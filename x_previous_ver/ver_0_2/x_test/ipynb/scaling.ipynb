# %%
import pandas as pd
from aidds_buy.sys.utils.data_io import read_data

# %%
df = read_data(file_code='PP_LAST')

# %%
df.sample(5)
# Out:
#              ACC_NO  CONS_COST  ...  SL_SPEC_120.0  SL_SPEC_240.0
# 7381   474920214438    4782777  ...              0              0
# 2232   476920204455    9187344  ...              0              0
# 7394   474920214503    3226803  ...              0              0
# 11745  474220233216    8256454  ...              0              0
# 4301   477220223911    2944375  ...              0              0
#
# [5 rows x 105 columns]
